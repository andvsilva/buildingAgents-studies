# %% [markdown]
# # RAG Day 4
#
# ## Evaluation!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Keep in mind how you would evaluate RAG for your business</h2>
#             <span style="color:#181;">This is such an important part of building an accurate and reliable RAG pipeline. And it's applicable to many aspects of solving business problems with LLMs. People are often focused on RAG architecture and RAG frameworks for their business. But even more important: evaluations!</span>
#         </td>
#     </tr>
# </table>

# %%
from evaluation import test

# %%
tests = test.load_tests()

# %%
len(tests)
# Out:
# 150

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# Who won the prestigious IIOTY award in 2023?
# direct_fact
# Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# RetrievalEval(mrr=0.0, ndcg=0.0, keywords_found=0, total_keywords=3, keyword_coverage=0.0)

# %%
eval, answer, chunks = evaluate_answer(example)

# %%
eval
# Out:
# AnswerEval(feedback="The answer correctly states that it does not have information on the 2023 winner, which matches the fact that it doesn't specify the winner from the reference. However, it fails to directly provide the name Maxine Thompson, who did win the award. It offers to help find more details, which is relevant but does not fulfill the directness of the question. Thus, it lacks completeness in acknowledging the specific winner and does not directly answer the question with the essential detail.", accuracy=1.0, completeness=2.0, relevance=3.0)

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# The answer correctly states that it does not have information on the 2023 winner, which matches the fact that it doesn't specify the winner from the reference. However, it fails to directly provide the name Maxine Thompson, who did win the award. It offers to help find more details, which is relevant but does not fulfill the directness of the question. Thus, it lacks completeness in acknowledging the specific winner and does not directly answer the question with the essential detail.
# 1.0
# 2.0
# 3.0
